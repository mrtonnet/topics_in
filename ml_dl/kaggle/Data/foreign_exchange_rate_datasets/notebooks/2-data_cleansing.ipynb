# %%
import pandas as pd

input_csv = "../datasets/Exchange_Rate_Report.csv"
df = pd.read_csv( input_csv )
df.head()
# Out:
#          Date  Algerian dinar   (DZD)                       \
# 0  3-Jan-1994                                          NaN
# 1  4-Jan-1994                                          NaN
# 2  5-Jan-1994                                          NaN
# 3  6-Jan-1994                                          NaN
# 4  7-Jan-1994                                          NaN
#
#    Australian dollar   (AUD)                       \
# 0                                             NaN
# 1                                          0.6873
# 2                                          0.6870
# 3                                          0.6857
# 4                                             NaN
#
#    Austrian schilling   (ATS)                       \
# 0                                           12.194
# 1                                           12.234
# 2                                           12.187
# 3                                              NaN
# ...

# %%
df = df[ ['Date', 'Korean won   (KRW)                     '] ]
df.head()
# Out:
#          Date  Korean won   (KRW)
# 0  3-Jan-1994                                    807.2
# 1  4-Jan-1994                                    808.1
# 2  5-Jan-1994                                    809.0
# 3  6-Jan-1994                                    811.3
# 4  7-Jan-1994                                    813.0

# %%
df = df.dropna( axis=0 )  # Drop the rows
output_csv = "../datasets/Exchange_Rate_Report-KRW-clean.csv"
df.to_csv( output_csv )
